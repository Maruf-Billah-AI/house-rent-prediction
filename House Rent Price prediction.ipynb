# %%
#Import Library

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Dhaka Rent.csv')

# %%
df
# Out:
#     area   rent
# 0   2000  31500
# 1   2100  35000
# 2   2500  41050
# 3   2250  36100
# 4   3000  52100
# 5   1900  32500
# 6   1500  20000
# 7   1850  24500
# 8   2700  48000
# 9   2100  31000
# 10  2150  34500
# 11  2100  32000
# 12  2100  34500
# 13  2510  40050
# 14  2250  34100
# 15  3100  51500
# 16  1800  30500
# 17  1550  21000
# 18  1800  25000
# 19  2700  47000
# 20  2110  31500
# 21  2100  33500
# 22  3500  70000
# 23  1200  20000
# 24  2800  50000
# 25  3100  53000
# 26  2750  48000
# 27  1800  25000
# 28  2200  31460
# 29  3100  51400
# 30  2100  33500
# 31  2100  35010
# 32  2500  41100
# 33  2250  35100
# 34  3000  52200
# 35  1900  32300
# 36  1500  20200
# 37  1850  24000
# 38  2700  47500
# 39  2100  31500
# 40  2150  34400
# 41  2100  32020
# 42  2100  34700
# 43  2510  40000
# 44  2250  35000
# 45  3100  51000
# 46  1800  30000
# 47  1550  21500
# 48  1800  25500
# 49  2700  47500
# 50  2110  31000
# 51  2100  33000
# 52  3500  70500
# 53  1200  20100
# ...

# %%
df.head()
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100

# %%
df.head(10)
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100
# 5  1900  32500
# 6  1500  20000
# 7  1850  24500
# 8  2700  48000
# 9  2100  31000

# %%
df.shape
# Out:
# (60, 2)

# %%
#Check Null Value

df.isnull().any()
# Out:
# area    False
# rent    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# area    0
# rent    0
# dtype: int64

# %%
x = df[['area']]
y = df[['rent']]

# %%
#Visualization

plt.scatter(df['area'],df['rent'], marker='.', color='blue')

plt.xlabel('Area in square feet')
plt.ylabel('Rent in Taka')
# Out:
# Text(0, 0.5, 'Rent in Taka')

# %%
df.head()
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100

# %%
df.shape
# Out:
# (60, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=.4, random_state=1)

# %%
xtrain
# Out:
#     area
# 49  2700
# 32  2500
# 47  1550
# 38  2700
# 55  3100
# 13  2510
# 22  3500
# 51  2100
# 30  2100
# 34  3000
# 23  1200
# 4   3000
# 14  2250
# 29  3100
# 28  2200
# 54  2800
# 58  2200
# 18  1800
# 59  3100
# 20  2110
# 25  3100
# 6   1500
# 45  3100
# 7   1850
# 57  1800
# 1   2100
# 16  1800
# 0   2000
# 15  3100
# 5   1900
# 11  2100
# 9   2100
# 8   2700
# 12  2100
# 43  2510
# 37  1850

# %%
ytrain
# Out:
#      rent
# 49  47500
# 32  41100
# 47  21500
# 38  47500
# 55  54000
# 13  40050
# 22  70000
# 51  33000
# 30  33500
# 34  52200
# 23  20000
# 4   52100
# 14  34100
# 29  51400
# 28  31460
# 54  51000
# 58  31560
# 18  25000
# 59  51600
# 20  31500
# 25  53000
# 6   20000
# 45  51000
# 7   24500
# 57  25100
# 1   35000
# 16  30500
# 0   31500
# 15  51500
# 5   32500
# 11  32000
# 9   31000
# 8   48000
# 12  34500
# 43  40000
# 37  24000

# %%
xtest
# Out:
#     area
# 39  2100
# 41  2100
# 2   2500
# 48  1800
# 50  2110
# 44  2250
# 33  2250
# 35  1900
# 40  2150
# 27  1800
# 24  2800
# 53  1200
# 46  1800
# 3   2250
# 26  2750
# 36  1500
# 21  2100
# 10  2150
# 52  3500
# 19  2700
# 42  2100
# 56  2750
# 17  1550
# 31  2100

# %%
ytest
# Out:
#      rent
# 39  31500
# 41  32020
# 2   41050
# 48  25500
# 50  31000
# 44  35000
# 33  35100
# 35  32300
# 40  34400
# 27  25000
# 24  50000
# 53  20100
# 46  30000
# 3   36100
# 26  48000
# 36  20200
# 21  33500
# 10  34500
# 52  70500
# 19  47000
# 42  34700
# 56  48500
# 17  21000
# 31  35010

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
reg.predict(xtest)
# Out:
# array([[32892.18541881],
#        [32892.18541881],
#        [41288.883212  ],
#        [26594.66207392],
#        [33102.10286364],
#        [36040.94709126],
#        [36040.94709126],
#        [28693.83652222],
#        [33941.77264296],
#        [26594.66207392],
#        [47586.4065569 ],
#        [13999.61538413],
#        [26594.66207392],
#        [36040.94709126],
#        [46536.81933275],
#        [20297.13872903],
#        [32892.18541881],
#        [33941.77264296],
#        [62280.62769498],
#        [45487.2321086 ],
#        [32892.18541881],
#        [46536.81933275],
#        [21346.72595318],
#        [32892.18541881]])

# %%
plt.scatter(df['area'],df['rent'], marker='.', color='blue')
plt.xlabel('Area in square feet')
plt.ylabel('Rent in Taka')

plt.plot(df.area, reg.predict(df[['area']]))

# %%
reg.predict([[3500]])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[62280.62769498]])

# %%
#y = mx + c

reg.coef_
# Out:
# array([[20.99174448]])

# %%
reg.intercept_
# Out:
# array([-11190.47799544])

# %%
# m=coefficient, x=area,c= intercept

y = 20.99174448*3500 - 11190.47799544

# %%
y
# Out:
# 62280.62768456001
